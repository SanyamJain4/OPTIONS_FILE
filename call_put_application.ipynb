# %% [markdown]
# ## **ASSIGNMENT-1**

# %% [markdown]
# **Importing Libraries**

# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import date
import warnings
import yfinance as yf

# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Importing Options Data**

# %%
symbol = "^SPX"
dfo = yf.Ticker(symbol)

# Get current price using historical data (more reliable than info)
current_price = dfo.history(period='1d')['Close'].iloc[-1]

# Select the next recent expiration date
expiration_date = dfo.options[1]
option_chain = dfo.option_chain(expiration_date)

# Extract Calls and Puts Data
calls = option_chain.calls
puts = option_chain.puts

# %% [markdown]
# **Call Option Data**

# %%
calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW250701C04700000 2025-06-27 16:16:46+00:00  4700.0    1486.63  1455.5
# 1    SPXW250701C04800000 2025-06-27 16:15:49+00:00  4800.0    1385.31  1355.4
# 2    SPXW250701C04900000 2025-06-27 18:40:39+00:00  4900.0    1239.33  1255.7
# 3    SPXW250701C05000000 2025-06-27 17:08:20+00:00  5000.0    1181.64  1155.4
# 4    SPXW250701C05175000 2025-06-26 15:11:07+00:00  5175.0     955.72   980.4
# ..                   ...                       ...     ...        ...     ...
# 141  SPXW250701C06525000 2025-06-27 19:31:03+00:00  6525.0       0.03     0.0
# 142  SPXW250701C06600000 2025-06-26 16:12:04+00:00  6600.0       0.05     0.0
# 143  SPXW250701C07000000 2025-06-23 18:23:09+00:00  7000.0       0.05     0.0
# 144  SPXW250701C07600000 2025-06-11 17:15:40+00:00  7600.0       0.05     0.0
# 145  SPXW250701C07800000 2025-06-25 15:23:15+00:00  7800.0       0.05     0.0
#
#          ask    change  percentChange  volume  openInterest  \
# 0    1480.70   0.00000       0.000000     4.0           0.0
# 1    1380.70   0.00000       0.000000     1.0           0.0
# 2    1280.50 -41.31006      -3.225736    21.0           0.0
# 3    1180.50   0.00000       0.000000     1.0           0.0
# 4    1005.80   0.00000       0.000000     NaN           5.0
# ..       ...       ...            ...     ...           ...
# 141     4.10   0.00000       0.000000     1.0           NaN
# 142     4.10   0.00000       0.000000     1.0          22.0
# 143     0.05   0.00000       0.000000     1.0           4.0
# 144     0.05   0.00000       0.000000     NaN           1.0
# 145     0.05   0.00000       0.000000     1.0           2.0
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             1.553591        True      REGULAR      USD
# 1             1.450259        True      REGULAR      USD
# 2             1.342227        True      REGULAR      USD
# 3             1.241886        True      REGULAR      USD
# 4             1.076421        True      REGULAR      USD
# ..                 ...         ...          ...      ...
# 141           0.365424       False      REGULAR      USD
# 142           0.424566       False      REGULAR      USD
# 143           0.434576       False      REGULAR      USD
# 144           0.656253       False      REGULAR      USD
# 145           0.734378       False      REGULAR      USD
#
# [146 rows x 14 columns]

# %% [markdown]
# **Put Option Data**

# %%
puts
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW250701P02400000 2025-06-02 13:40:21+00:00  2400.0       0.05     0.0
# 1    SPXW250701P02800000 2025-06-13 19:07:28+00:00  2800.0       0.10     0.0
# 2    SPXW250701P03000000 2025-06-17 18:00:35+00:00  3000.0       0.10     0.0
# 3    SPXW250701P03200000 2025-06-20 19:13:28+00:00  3200.0       0.05     0.0
# 4    SPXW250701P03400000 2025-06-17 17:49:22+00:00  3400.0       0.20     0.0
# ..                   ...                       ...     ...        ...     ...
# 164  SPXW250701P06350000 2025-06-27 14:32:01+00:00  6350.0     177.40   169.1
# 165  SPXW250701P06400000 2025-06-24 13:50:58+00:00  6400.0     325.61   219.1
# 166  SPXW250701P06425000 2025-06-27 20:00:02+00:00  6425.0     254.30   244.0
# 167  SPXW250701P06550000 2025-06-27 18:55:29+00:00  6550.0     413.51   368.8
# 168  SPXW250701P07200000 2025-06-11 12:36:48+00:00  7200.0    1121.40  1018.6
#
#         ask     change  percentChange  volume  openInterest  \
# 0       4.0   0.000000       0.000000    20.0          21.0
# 1       4.0   0.000000       0.000000    77.0          78.0
# 2       4.1   0.000000       0.000000     2.0          23.0
# 3       4.1   0.000000       0.000000    10.0          36.0
# 4       4.1   0.000000       0.000000     1.0          59.0
# ..      ...        ...            ...     ...           ...
# 164   194.2 -22.250000     -11.144504     1.0           5.0
# 165   244.1   0.000000       0.000000     NaN           1.0
# 166   269.0   0.000000       0.000000     8.0           0.0
# 167   393.9  40.149994      10.753695     3.0           NaN
# 168  1043.6   0.000000       0.000000     NaN           1.0
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             4.003911       False      REGULAR      USD
# 1             3.385988       False      REGULAR      USD
# 2             3.117922       False      REGULAR      USD
# 3             2.857913       False      REGULAR      USD
# 4             2.613529       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 164           0.329658        True      REGULAR      USD
# 165           0.385458        True      REGULAR      USD
# 166           0.411886        True      REGULAR      USD
# 167           0.539021        True      REGULAR      USD
# 168           0.843202        True      REGULAR      USD
#
# [169 rows x 14 columns]

# %% [markdown]
# ## **Payoff Calculation**

# %% [markdown]
#  **Call option**
#
# payoff=max(-C, S - X - C)

# %% [markdown]
#  **Put option**
#
# payoff=max(-P, X - S - P)

# %% [markdown]
# where,
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
    """
    Calculate the payoff for an option position

    Parameters:
    option_type (str): 'C' for Call, 'P' for Put
    premium (float): Option premium
    S (array): Array of possible stock prices
    X (float): Strike price
    """
    payoff_value = 0
    if option_type == 'C':  # Call Option
        payoff_value = np.maximum(-premium,S-X-premium)
    elif option_type == 'P':  # Put Option
        payoff_value = np.maximum(-premium,X-S-premium)
    else:
        raise ValueError("Option type not supported")
    return payoff_value

# %% [markdown]
# **Checking the output of payoff function**

# %%
payoff('C', 10, 120,100)  #answer displayed should be 10
# Out:
# np.int64(10)

# %%
payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-7-2021870287.py in <cell line: 0>()
# ----> 1 payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
#
# /tmp/ipython-input-5-1334379971.py in payoff(option_type, premium, S, X)
#      15         payoff_value = np.maximum(-premium,X-S-premium)
#      16     else:
# ---> 17         raise ValueError("Option type not supported")
#      18     return payoff_value
#
# ValueError: Option type not supported

# %%
payoff('P', 10, 120, 100)  #answer displayed should be -10
# Out:
# np.int64(-10)

# %% [markdown]
# **Plot for Call Option**

# %%
# Call Option Plot
X_call = calls['strike'].iloc[0]  # Using first strike price
premium_call = calls['lastPrice'].iloc[0]

# Create stock price range based on current price
price_range = 0.5  # 50% above and below current price
StockPrice = np.linspace(current_price * (1 - price_range),
                        current_price * (1 + price_range),
                        1000)

# Calculate payoff (vectorized)
Payoff_Call = payoff('C', premium_call, StockPrice, X_call)

# Plot the call option payoff
plt.figure(figsize=(10, 6))
plt.plot(StockPrice, Payoff_Call, label='Call Option Payoff')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.axvline(x=X_call + premium_call, color='red', linestyle='--', label='Breakeven Point')
plt.xlabel('Stock Price')
plt.ylabel('Payoff ($)')
plt.title(f'Call Option Payoff at Expiry (Strike: ${X_call:,.2f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Plot for Put Option**

# %%
# Put Option Plot
X_put = puts['strike'].iloc[-1]  # Using last strike price
premium_put = puts['lastPrice'].iloc[-1]

# Create stock price range based on current price
price_range = 0.5  # 50% above and below current price
StockPrice = np.linspace(current_price * (1 - price_range),
                        current_price * (1 + price_range),
                        1000)

# Calculate payoff (vectorized)
Payoff_Put = payoff('P', premium_put, StockPrice, X_put)

# Plot the put option payoff
plt.figure(figsize=(10, 6))
plt.plot(StockPrice, Payoff_Put, label='Put Option Payoff')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.axvline(x=X_put - premium_put, color='red', linestyle='--', label='Breakeven Point')
plt.xlabel('Stock Price')
plt.ylabel('Payoff ($)')
plt.title(f'Put Option Payoff at Expiry (Strike: ${X_put:,.2f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Checking for ITM,OTM,ATM**

# %%
# Option Classification function
def classify_option(S, X,option_type):
    """
    Classify option as ITM, ATM, or OTM based on current stock price(S) and strike price(X)
    """
    if(option_type=="C"):
      if (S<X):
        return "In the Money (ITM)"
      elif (S==X):
        return "At the Money (ATM)"
      else:
        return "Out of the Money (OTM)"
    elif(option_type=="P"):
      if (S>X):
        return "In the Money (ITM)"
      elif (S==X):
        return "At the Money (ATM)"
      else:
        return "Out of the Money (OTM)"

# %%
# Example classification
classification_call = classify_option(current_price, X_call,'C')
classification_put = classify_option(current_price, X_put,'P')
print(f"\nCall Option Classification: {classification_call}")
print(f"Put Option Classification: {classification_put}")
# Out:
# Call Option Classification: Out of the Money (OTM)
# Put Option Classification: Out of the Money (OTM)

# %% [markdown]
# **Put Call Parity Validation**

# %%
# Put-Call Parity Validation
def validate_put_call_parity(S, X, premium_call, premium_put, r=0.05, T=1):
    """
    Validate Put-Call Parity relationship

    Parameters:
    S: Current stock price
    X: Strike price
    premium_call: Call option premium
    premium_put: Put option premium
    r: Risk-free interest rate (default 5%)
    T: Time to maturity in years (default 1 year)
    """
    left_hand_side = S + premium_put
    right_hand_side = premium_call + X/((1+r)**T)
    return np.isclose(left_hand_side, right_hand_side, rtol=1e-2)

# %% [markdown]
# **Check put-call parity**

# %%
# Check put-call parity
is_parity_valid = validate_put_call_parity(current_price, X_call, premium_call, premium_put)
print(f"\nDoes Put-Call Parity Hold? {is_parity_valid}")
# Out:
# Does Put-Call Parity Hold? False
